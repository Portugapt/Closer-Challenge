# %%
## Utility and Data Wrangling
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

## Plotting and Viz
import matplotlib.pyplot as plt
import seaborn as sns
import graphviz
import scipy.stats as stats

# %%
dataset = pd.read_csv('20220411-161754_dataset.csv')

# %%
dfInsurance = dataset.copy()

# %%
clusters_2 = pd.read_csv('clusters_1.csv')

# %%
dfInsurance = dfInsurance.merge(clusters_2, on = 'cod_cust_id')

# %%
dfInsurance.head()
# Out:
#    cod_cust_id  dt_fpy  atr_cust_age      dsc_edu_deg  amt_gms  atr_gla  \
# 0            1    1985            34  2 - High School   4354.0        1
# 1            2    1981            21  2 - High School   1353.0        4
# 2            3    1991            46        1 - Basic   4554.0        3
# 3            4    1990            35      3 - BSc/MSc   2197.0        4
# 4            5    1986            43      3 - BSc/MSc   3526.0        4
#
#    flg_children  amt_cmv     rt_cr  amt_plob_motor  ...  fe_bin_plob_wcomp  \
# 0             1   380.97  0.390032          375.85  ...                  D
# 1             1  -131.13  1.116503           77.46  ...                  A
# 2             0   504.67  0.284810          206.15  ...                  A
# 3             1   -16.99  0.986665          182.48  ...                  C
# 4             1    35.23  0.904281          338.62  ...                  C
#
#    fe_bin_plob_household  fe_cmv_cr_quadrant_Type1  fe_cmv_cr_quadrant_Type2  \
# 0                      F                        Q2                        Q3
# 1                      B                        Q4                        Q4
# 2                      D                        Q2                        Q3
# 3                      F                        Q2                        Q4
# 4                      F                        Q2                        Q4
#
#    fe_amt_plob_motor_scale fe_amt_plob_life_scale  fe_amt_plob_health_scale  \
# 0                  4.84396                4.49746                   2.85159
# 1                  1.85994                7.23583                   2.35626
# 2                  3.66995                6.00000                   2.48798
# 3                  3.25395                3.97534                   3.54088
# 4                  4.63484                2.36454                   3.09260
#
#   fe_amt_plob_wcomp_scale  fe_amt_plob_household_scale  Clusters_1
# 0                 1.67637                      1.87083           2
# 1                 4.08612                      5.29662           3
# 2                 4.06937                      3.68586           3
# 3                 2.26907                      1.34688           2
# 4                 2.86798                      1.41147           0
#
# [5 rows x 37 columns]

# %%
dfInsurance.shape
# Out:
# (10270, 37)

# %%
dfInsurance.isna().sum()
# Out:
# cod_cust_id                       0
# dt_fpy                            0
# atr_cust_age                      0
# dsc_edu_deg                      17
# amt_gms                           0
# atr_gla                           0
# flg_children                      0
# amt_cmv                           0
# rt_cr                             0
# amt_plob_motor                    0
# amt_plob_household                0
# amt_plob_health                   0
# amt_plob_life                     0
# amt_plob_wcomp                    0
# atr_edu_deg                       0
# outlier_candidate              9555
# amt_premium_total                 0
# DATA_MAIN_CUT                     0
# atr_fpy_to_date                   0
# rt_plob_life                      0
# rt_plob_household                 0
# rt_plob_motor                     0
# rt_plob_health                    0
# rt_plob_wcomp                     0
# fe_bin_plob_motor                 0
# fe_bin_plob_life                  0
# fe_bin_plob_health                0
# fe_bin_plob_wcomp                 0
# fe_bin_plob_household             0
# fe_cmv_cr_quadrant_Type1          0
# fe_cmv_cr_quadrant_Type2          0
# fe_amt_plob_motor_scale           0
# fe_amt_plob_life_scale            0
# fe_amt_plob_health_scale          0
# fe_amt_plob_wcomp_scale           0
# fe_amt_plob_household_scale       0
# Clusters_1                        0
# dtype: int64

# %%
dfInsurance.dtypes
# Out:
# cod_cust_id                      int64
# dt_fpy                           int64
# atr_cust_age                     int64
# dsc_edu_deg                     object
# amt_gms                        float64
# atr_gla                          int64
# flg_children                     int64
# amt_cmv                        float64
# rt_cr                          float64
# amt_plob_motor                 float64
# amt_plob_household             float64
# amt_plob_health                float64
# amt_plob_life                  float64
# amt_plob_wcomp                 float64
# atr_edu_deg                    float64
# outlier_candidate               object
# amt_premium_total              float64
# DATA_MAIN_CUT                   object
# atr_fpy_to_date                float64
# rt_plob_life                   float64
# rt_plob_household              float64
# rt_plob_motor                  float64
# rt_plob_health                 float64
# rt_plob_wcomp                  float64
# fe_bin_plob_motor               object
# fe_bin_plob_life                object
# fe_bin_plob_health              object
# fe_bin_plob_wcomp               object
# fe_bin_plob_household           object
# fe_cmv_cr_quadrant_Type1        object
# fe_cmv_cr_quadrant_Type2        object
# fe_amt_plob_motor_scale        float64
# fe_amt_plob_life_scale         float64
# fe_amt_plob_health_scale       float64
# fe_amt_plob_wcomp_scale        float64
# fe_amt_plob_household_scale    float64
# Clusters_1                       int64
# dtype: object

# %%
dfInsurance['dt_fpy'] = dfInsurance['dt_fpy'].astype('int64')
dfInsurance['atr_cust_age'] = dfInsurance['atr_cust_age'].astype('int64')
dfInsurance['atr_gla'] = dfInsurance['atr_gla'].astype('int64')
dfInsurance['flg_children'] = dfInsurance['flg_children'].astype('int64')

#dfInsurance['dt_fpy'] = pd.to_datetime(dfInsurance['dt_fpy'], format='%Y')

#dfInsurance.drop('Unnamed: 0', axis=1, inplace=True)

# %%
def interquartile_range(column):
    """Checks if data is 1.5 times the interquartile range greater than the third quartile (Q3) 
    or 1.5 times the interquartile range less than the first quartile (Q1)
    
    param column: a series or column from a dataset containing numerical data 
    output: returns the superior and inferior values where observations are below or above 1.5 times the interquartile range 
    """
    distance = 1.5 * (np.nanpercentile(column, 75) - np.nanpercentile(column, 25))
    lim_sup= distance + np.nanpercentile(column, 90)
    lim_inf= np.nanpercentile(column, 10) - distance
    
    return lim_sup, lim_inf

# %%
#negatives
dfInsurance.loc[(dfInsurance['amt_plob_motor'] < 0) | (dfInsurance['amt_plob_household'] < 0) | (dfInsurance['amt_plob_health'] < 0) | (dfInsurance['amt_plob_life'] < 0) | (dfInsurance['amt_plob_wcomp'] < 0)]
dfInsurance.loc[(dfInsurance['amt_plob_motor'] < 0)] # 1
dfInsurance.loc[(dfInsurance['amt_plob_household'] < 0)] # 1092
dfInsurance.loc[(dfInsurance['amt_plob_health'] < 0)] # 1
dfInsurance.loc[(dfInsurance['amt_plob_life'] < 0)] # 666
dfInsurance.loc[(dfInsurance['amt_plob_wcomp'] < 0)] # 926
# Out:
#        cod_cust_id  dt_fpy  atr_cust_age      dsc_edu_deg  amt_gms  atr_gla  \
# 28              29    1995            64      3 - BSc/MSc   7277.0        4
# 29              30    1980            44      3 - BSc/MSc   5320.0        3
# 30              31    1988            41  2 - High School   4295.0        4
# 51              52    1982            50      3 - BSc/MSc   6467.0        4
# 64              65    1982            43      3 - BSc/MSc   4587.0        3
# ...            ...     ...           ...              ...      ...      ...
# 10217        10244    1988            46          4 - PhD   4555.0        1
# 10222        10249    1977            49  2 - High School   4421.0        4
# 10228        10255    1994            53      3 - BSc/MSc   3880.0        1
# 10229        10256    1980            71      3 - BSc/MSc   7896.0        4
# 10238        10265    1976            50      3 - BSc/MSc   4686.0        1
#
#        flg_children   amt_cmv      rt_cr  amt_plob_motor  ...  \
# 28                0    264.17   0.496325          301.28  ...
# 29                0      2.00   0.955454          524.21  ...
# 30                1    427.76   0.190213          483.09  ...
# 51                1 -14714.08  25.360000          557.44  ...
# 64                0   -124.32   1.188979          452.53  ...
# ...             ...       ...        ...             ...  ...
# 10217             1    500.55   0.192704          569.55  ...
# 10222             1    -10.32   0.974868          484.87  ...
# 10228             1    516.44   0.075347          529.99  ...
# 10229             0    -28.22   1.005691          423.19  ...
# 10238             1     -2.10   0.963190          481.98  ...
#
#        fe_bin_plob_wcomp  fe_bin_plob_household  fe_cmv_cr_quadrant_Type1  \
# 28             NEGATIVES                      G                        Q2
# 29             NEGATIVES                      F                        Q2
# 30             NEGATIVES              NEGATIVES                        Q2
# 51             NEGATIVES                      F                        Q4
# 64             NEGATIVES              NEGATIVES                        Q1
# ...                  ...                    ...                       ...
# 10217          NEGATIVES                      F                        Q2
# 10222          NEGATIVES                      G                        Q2
# 10228          NEGATIVES                      G                        Q2
# 10229          NEGATIVES                      G                        Q1
# 10238          NEGATIVES                      F                        Q2
#
#        fe_cmv_cr_quadrant_Type2  fe_amt_plob_motor_scale  \
# 28                           Q3                  4.42510
# 29                           Q4                  5.66278
# 30                           Q3                  5.43550
# 51                           Q1                  5.01314
# 64                           Q4                  5.26658
# ...                         ...                      ...
# 10217                        Q3                  5.91339
# 10222                        Q4                  5.44533
# 10228                        Q3                  5.69473
# 10229                        Q4                  5.10441
# 10238                        Q4                  5.42936
#
#       fe_amt_plob_life_scale  fe_amt_plob_health_scale  \
# 28                  -1.56459                   3.35568
# 29                   0.96020                   1.15976
# 30                   0.49837                   1.93751
# 51                   0.62200                   0.00000
# 64                   2.28169                   2.15960
# ...                      ...                       ...
# 10217               -1.56459                   0.76609
# 10222               -1.27431                   1.73610
# 10228                0.36620                   0.85486
# 10229                0.63053                   2.55292
# 10238                2.36454                   1.90044
#
#       fe_amt_plob_wcomp_scale  fe_amt_plob_household_scale  Clusters_1
# 28                   -1.00369                      1.00000           1
# 29                   -1.41344                      1.08055           1
# 30                   -1.42266                     -1.19409           1
# 51                   -2.00000                      1.00000           1
# 64                   -1.33886                     -1.60443           1
# ...                       ...                          ...         ...
# 10217                -2.00000                      1.58853           2
# 10222                -1.01290                      1.00000           2
# 10228                -1.24585                      0.70333           1
# 10229                -1.32965                      0.63000           0
# 10238                -1.66482                      1.28229           3
#
# [926 rows x 37 columns]

# %% [markdown]
# # Check data distribution

# %% [markdown]
# #### Customer Monetary Value

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
dfInsurance['amt_gms'].plot(kind='hist', bins=20, ax=axes[0])
dfInsurance['amt_gms'].plot(kind='box', ax=axes[1])
plt.suptitle("Gross Monthly Salary")
# Out:
# Text(0.5, 0.98, 'Gross Monthly Salary')

# %%
dfInsurance = dfInsurance.loc[dfInsurance['amt_gms'] < 60000]

# %% [markdown]
# #### Customer Monetary Value

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
dfInsurance['amt_cmv'].plot(kind='hist', bins=20, ax=axes[0])
dfInsurance['amt_cmv'].plot(kind='box', ax=axes[1])
plt.suptitle("Customer Monetary Value")
# Out:
# Text(0.5, 0.98, 'Customer Monetary Value')

# %%
dfInsurance['amt_cmv'].min()
# Out:
# -165680.424

# %% [markdown]
# ##### Convert min value to 0

# %%
dfInsurance['test_feature'] = dfInsurance['amt_cmv'] + 165680.424

# %%
dfInsurance['test_feature'] = np.log(dfInsurance['test_feature'] + 1)

# %%
dfInsurance['test_feature'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
dfInsurance['test_feature'].describe()
# Out:
# count    10268.000000
# mean        12.017797
# std          0.118850
# min          0.000000
# 25%         12.017766
# 50%         12.018948
# 75%         12.020233
# max         12.087049
# Name: test_feature, dtype: float64

# %%
dfInsurance = dfInsurance.loc[dfInsurance['amt_cmv'] > -75000]

# %% [markdown]
# #### Claims Rate

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
dfInsurance['rt_cr'].plot(kind='hist', bins=20, ax=axes[0])
dfInsurance['rt_cr'].plot(kind='box', ax=axes[1])
plt.suptitle("Claims Rate")
# Out:
# Text(0.5, 0.98, 'Claims Rate')

# %%
dfInsurance.loc[dfInsurance['rt_cr'] > 2]
# Out:
#       cod_cust_id  dt_fpy  atr_cust_age      dsc_edu_deg  amt_gms  atr_gla  \
# 51             52    1982            50      3 - BSc/MSc   6467.0        4
# 112           113    1997            37          4 - PhD   4707.0        1
# 135           136    1997            28      3 - BSc/MSc   4352.0        4
# 653           656    1974            53      3 - BSc/MSc   6558.0        3
# 673           676    1994            79  2 - High School   8870.0        1
# 705           708    1991            25      3 - BSc/MSc   3267.0        1
# 756           759    1988            24      3 - BSc/MSc   2233.0        1
# 790           794    1980            33      3 - BSc/MSc   2739.0        3
# 914           918    1986            64  2 - High School   6710.0        4
# 948           952    1998            40      3 - BSc/MSc   3172.0        3
# 979           983    1989            35  2 - High School   3542.0        3
# 1022         1026    1988            77      3 - BSc/MSc   9131.0        1
# 7945         7963    1975            28          4 - PhD   3735.0        1
# 9623         9649    1990            66      3 - BSc/MSc   7147.0        3
#
#       flg_children     amt_cmv      rt_cr  amt_plob_motor  ...  \
# 51               1 -14714.0800  25.360000          557.44  ...
# 112              1  -8719.0425  15.650000          518.32  ...
# 135              1 -10198.9120  14.800000          297.61  ...
# 653              1 -64891.0000  96.000000          410.30  ...
# 673              0 -52382.7600  63.000000          197.48  ...
# 705              1 -28945.4000  35.000000          175.70  ...
# 756              1 -10107.3720  12.600000          193.37  ...
# 790              1  -7851.1720  13.900000          127.58  ...
# 914              0 -26130.4520  32.300000          135.58  ...
# 948              1  -2642.9060   5.600000          501.65  ...
# 979              1  -6115.8516   9.870000           83.35  ...
# 1022             1  -2082.8320   4.360000          370.07  ...
# 7945             1    -56.1000   4.329764          418.79  ...
# 9623             0 -37327.0800  69.000000          319.06  ...
#
#       fe_bin_plob_household  fe_cmv_cr_quadrant_Type1  \
# 51                        F                        Q4
# 112                       G                        Q4
# 135                       D                        Q4
# 653                       E                        Q4
# 673                       C                        Q4
# 705                       C                        Q4
# 756                       C                        Q4
# 790                       F                        Q4
# 914                       C                        Q4
# 948               NEGATIVES                        Q4
# 979                       E                        Q4
# 1022                      G                        Q4
# 7945              NEGATIVES                        Q1
# 9623              NEGATIVES                        Q4
#
#       fe_cmv_cr_quadrant_Type2  fe_amt_plob_motor_scale  \
# 51                          Q1                  5.01314
# 112                         Q1                  5.00965
# 135                         Q1                  4.16397
# 653                         Q1                  5.00000
# 673                         Q1                  4.00000
# 705                         Q1                  3.00000
# 756                         Q1                  3.81129
# 790                         Q1                  2.00000
# 914                         Q1                  3.00000
# 948                         Q1                  5.00816
# 979                         Q1                  2.00000
# 1022                        Q1                  4.91687
# 7945                        Q1                  5.00076
# 9623                        Q1                  4.38685
#
#       fe_amt_plob_life_scale fe_amt_plob_health_scale  \
# 51                   0.62200                  0.00000
# 112                  0.40000                  1.16622
# 135                  7.00000                  2.93872
# 653                  4.00000                  2.00000
# 673                  5.00000                  3.00392
# 705                  4.49202                  3.00454
# 756                  1.00000                  3.00392
# 790                  3.00000                  3.00824
# 914                  6.00000                  3.00196
# 948                 -1.00000                  2.00000
# 979                  5.47923                  3.00605
# 1022                 2.00000                  3.00081
# 7945                 2.00000                  3.00000
# 9623                 0.60000                  3.00280
#
#       fe_amt_plob_wcomp_scale fe_amt_plob_household_scale  Clusters_1  \
# 51                   -2.00000                     1.00000           1
# 112                   1.20000                     0.00000           1
# 135                  -1.14286                     3.00000           2
# 653                   2.00000                     2.38650           1
# 673                   3.00000                     4.00000           2
# 705                   1.83492                     4.49649           2
# 756                   3.00000                     4.79451           0
# 790                   1.40000                     1.44366           1
# 914                   4.00352                     4.12061           2
# 948                  -1.00000                    -1.44500           1
# 979                   4.00000                     2.00000           3
# 1022                  2.06337                     1.00000           2
# 7945                  1.31746                    -1.00000           2
# 9623                  1.00000                    -2.00000           3
#
#       test_feature
# 51       11.924819
# 112      11.963761
# 135      11.954289
# 653      11.520799
# 673      11.637783
# 705      11.825808
# 756      11.954877
# 790      11.969275
# 914      11.846185
# 948      12.001742
# 979      11.980210
# 1022     12.005171
# 7945     12.017483
# 9623     11.762550
#
# [14 rows x 38 columns]

# %% [markdown]
# #### Premiums Motor

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
dfInsurance['amt_plob_motor'].plot(kind='hist', bins=20, ax=axes[0])
dfInsurance['amt_plob_motor'].plot(kind='box', ax=axes[1])
plt.suptitle("Motor premiums")
# Out:
# Text(0.5, 0.98, 'Motor premiums')

# %% [markdown]
# #### Premiums household

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
dfInsurance['amt_plob_household'].plot(kind='hist', bins=20, ax=axes[0])
dfInsurance['amt_plob_household'].plot(kind='box', ax=axes[1])
plt.suptitle("Household premiums")
# Out:
# Text(0.5, 0.98, 'Household premiums')

# %%
dfInsurance.loc[dfInsurance['amt_plob_household'] > 20000]
# Out:
#       cod_cust_id  dt_fpy  atr_cust_age      dsc_edu_deg  amt_gms  atr_gla  \
# 8844         8867    1978            44  2 - High School   5236.0        4
#
#       flg_children  amt_cmv     rt_cr  amt_plob_motor  ...  \
# 8844             1   473.54  0.980537          508.43  ...
#
#       fe_bin_plob_household  fe_cmv_cr_quadrant_Type1  \
# 8844                      A                        Q2
#
#       fe_cmv_cr_quadrant_Type2  fe_amt_plob_motor_scale  \
# 8844                        Q1                  5.00877
#
#       fe_amt_plob_life_scale fe_amt_plob_health_scale  \
# 8844                 1.27007                  0.57699
#
#       fe_amt_plob_wcomp_scale fe_amt_plob_household_scale  Clusters_1  \
# 8844                  1.30582                         7.0           1
#
#       test_feature
# 8844     12.020676
#
# [1 rows x 38 columns]

# %% [markdown]
# #### Premiums health

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
dfInsurance['amt_plob_health'].plot(kind='hist', bins=20, ax=axes[0])
dfInsurance['amt_plob_health'].plot(kind='box', ax=axes[1])
plt.suptitle("Health premiums")
# Out:
# Text(0.5, 0.98, 'Health premiums')

# %%
dfInsurance.loc[dfInsurance['amt_plob_health'] > 25000]
# Out:
#       cod_cust_id  dt_fpy  atr_cust_age      dsc_edu_deg  amt_gms  atr_gla  \
# 9127         9150    1985            22  2 - High School   1974.0        3
#
#       flg_children  amt_cmv     rt_cr  amt_plob_motor  ...  \
# 9127             1   804.05  0.971735           26.34  ...
#
#       fe_bin_plob_household  fe_cmv_cr_quadrant_Type1  \
# 9127                      A                        Q2
#
#       fe_cmv_cr_quadrant_Type2  fe_amt_plob_motor_scale  \
# 9127                        Q1                      1.0
#
#       fe_amt_plob_life_scale fe_amt_plob_health_scale  \
# 9127                     5.0                      4.0
#
#       fe_amt_plob_wcomp_scale fe_amt_plob_household_scale  Clusters_1  \
# 9127                  4.02363                     6.00885           0
#
#       test_feature
# 9127     12.022663
#
# [1 rows x 38 columns]

# %% [markdown]
# #### Premiums life

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
dfInsurance['amt_plob_life'].plot(kind='hist', bins=20, ax=axes[0])
dfInsurance['amt_plob_life'].plot(kind='box', ax=axes[1])
plt.suptitle("Life premiums")
# Out:
# Text(0.5, 0.98, 'Life premiums')

# %% [markdown]
# #### Premiums Work Compensation

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
dfInsurance['amt_plob_wcomp'].plot(kind='hist', bins=20, ax=axes[0])
dfInsurance['amt_plob_wcomp'].plot(kind='box', ax=axes[1])
plt.suptitle("Work Compensation premiums")
# Out:
# Text(0.5, 0.98, 'Work Compensation premiums')

# %%
dfInsurance.loc[dfInsurance['amt_plob_wcomp'] > 750]
# Out:
#       cod_cust_id  dt_fpy  atr_cust_age      dsc_edu_deg  amt_gms  atr_gla  \
# 5072         5085    1994            57  2 - High School   6659.0        3
# 7944         7962    1995            74      3 - BSc/MSc   8003.0        3
#
#       flg_children  amt_cmv     rt_cr  amt_plob_motor  ...  \
# 5072             0  2314.21  0.135528          350.51  ...
# 7944             0  1457.99  0.831583          431.86  ...
#
#       fe_bin_plob_household  fe_cmv_cr_quadrant_Type1  \
# 5072                      D                        Q2
# 7944                      E                        Q2
#
#       fe_cmv_cr_quadrant_Type2  fe_amt_plob_motor_scale  \
# 5072                        Q2                  4.71363
# 7944                        Q1                  5.00193
#
#       fe_amt_plob_life_scale fe_amt_plob_health_scale  \
# 5072                 4.13716                  2.59538
# 7944                 2.00000                  3.25460
#
#       fe_amt_plob_wcomp_scale fe_amt_plob_household_scale  Clusters_1  \
# 5072                  5.00000                     4.00000           1
# 7944                  4.44162                     2.19325           1
#
#       test_feature
# 5072     12.031693
# 7944     12.026584
#
# [2 rows x 38 columns]

# %% [markdown]
# ## Geographic location area

# %%
#lim_sup, lim_inf = interquartile_range(dfInsurance['amt_cmv'])

#plt.figure(figsize=(10, 8));
#sns.barplot(x='dsc_edu_deg', y='amt_cmv', data=dfInsurance.loc[(dfInsurance['amt_cmv'] < lim_sup) & (dfInsurance['amt_cmv'] > lim_inf)], ci=None, palette='tab10');
#plt.xlabel('Educational Degree', fontsize=16);
#plt.ylabel## Geographic location area('Customer Monetary Value', fontsize=16);
#plt.title('Customer Monetary Value vs Educational Degree', fontsize= 18);

# %% [markdown]
# #### Customer Monetary Value

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='amt_cmv', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location Area', fontsize=10);
plt.ylabel('Customer Monetary Value', fontsize=10);
plt.title('Customer Monetary Value vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# #### Claims rate

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='rt_cr', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location Area', fontsize=10);
plt.ylabel('Claim rates', fontsize=10);
plt.title('Claim rates vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# #### Gross Monthly Salary

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='amt_gms', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location', fontsize=10);
plt.ylabel('Gross Monthly Salary', fontsize=10);
plt.title('Gross Monthly Salary vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# #### Total premium

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='amt_premium_total', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location Area', fontsize=10);
plt.ylabel('Gross Monthly Salary', fontsize=10);
plt.title('Total premium vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# #### Motor premium

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='amt_plob_motor', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location Area', fontsize=10);
plt.ylabel('Gross Monthly Salary', fontsize=10);
plt.title('Motor premiums vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# #### Household premium

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='amt_plob_household', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location Area', fontsize=10);
plt.ylabel('Gross Monthly Salary', fontsize=10);
plt.title('Household Premiums vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# #### Health premium

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='amt_plob_health', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location Area', fontsize=10);
plt.ylabel('Health premiums', fontsize=10);
plt.title('Health premiums vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# #### Life premium

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='amt_plob_life', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location Area', fontsize=10);
plt.ylabel('Life premiums', fontsize=10);
plt.title('Life premiums vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# #### Work compensation premium

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='atr_gla', y='amt_plob_wcomp', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Geographic Location Area', fontsize=10);
plt.ylabel('Work compensation premiums', fontsize=10);
plt.title('Work compensation premiums vs Geographic Location Area', fontsize= 12);

# %% [markdown]
# ## Educational degree

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='amt_gms', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Gross monthly salary', fontsize=10);
plt.title('Gross monthly salary vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='amt_cmv', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Customer monetary value', fontsize=10);
plt.title('Customer monetary value vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='rt_cr', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Claims rate', fontsize=10);
plt.title('Claims rate vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='amt_premium_total', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Total premiums', fontsize=10);
plt.title('Total premiums vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='amt_plob_motor', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Motor premiums', fontsize=10);
plt.title('Motor premiums vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='amt_plob_household', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Household premiums', fontsize=10);
plt.title('Household premiums vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='amt_plob_health', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Health premiums', fontsize=10);
plt.title('Health premiums vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='amt_plob_life', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Life premiums', fontsize=10);
plt.title('Life premiums vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='amt_plob_wcomp', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Work compensation premiums', fontsize=10);
plt.title('Work compensation premiums vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='atr_cust_age', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('Customer age', fontsize=10);
plt.title('Customer age vs Educational degree', fontsize= 12);

# %%
plt.figure(figsize=(6, 4));
sns.barplot(x='dsc_edu_deg', y='dt_fpy', data=dfInsurance, ci=None, palette='tab10');
plt.xlabel('Educational degree', fontsize=10);
plt.ylabel('First policy year', fontsize=10);
plt.title('First policy year vs Educational degree', fontsize= 12);

# %%
dfInsurance.head()
# Out:
#    cod_cust_id  dt_fpy  atr_cust_age      dsc_edu_deg  amt_gms  atr_gla  \
# 0            1    1985            34  2 - High School   4354.0        1
# 1            2    1981            21  2 - High School   1353.0        4
# 2            3    1991            46        1 - Basic   4554.0        3
# 3            4    1990            35      3 - BSc/MSc   2197.0        4
# 4            5    1986            43      3 - BSc/MSc   3526.0        4
#
#    flg_children  amt_cmv     rt_cr  amt_plob_motor  ...  \
# 0             1   380.97  0.390032          375.85  ...
# 1             1  -131.13  1.116503           77.46  ...
# 2             0   504.67  0.284810          206.15  ...
# 3             1   -16.99  0.986665          182.48  ...
# 4             1    35.23  0.904281          338.62  ...
#
#    fe_bin_plob_household  fe_cmv_cr_quadrant_Type1  fe_cmv_cr_quadrant_Type2  \
# 0                      F                        Q2                        Q3
# 1                      B                        Q4                        Q4
# 2                      D                        Q2                        Q3
# 3                      F                        Q2                        Q4
# 4                      F                        Q2                        Q4
#
#    fe_amt_plob_motor_scale  fe_amt_plob_life_scale fe_amt_plob_health_scale  \
# 0                  4.84396                 4.49746                  2.85159
# 1                  1.85994                 7.23583                  2.35626
# 2                  3.66995                 6.00000                  2.48798
# 3                  3.25395                 3.97534                  3.54088
# 4                  4.63484                 2.36454                  3.09260
#
#    fe_amt_plob_wcomp_scale fe_amt_plob_household_scale  Clusters_1  \
# 0                  1.67637                     1.87083           2
# 1                  4.08612                     5.29662           3
# 2                  4.06937                     3.68586           3
# 3                  2.26907                     1.34688           2
# 4                  2.86798                     1.41147           0
#
#    test_feature
# 0     12.020119
# 1     12.017030
# 2     12.020863
# 3     12.017720
# 4     12.018035
#
# [5 rows x 38 columns]

# %%
def scatterplots_views(columnName):
    
    lim_sup, lim_inf = interquartile_range(dfInsurance[columnName])

    fig, axes = plt.subplots(3, 2, figsize=(15,12))
    #educational degree
    sns.scatterplot(x='atr_cust_age', y=columnName, hue='dsc_edu_deg', data=dfInsurance.loc[(dfInsurance[columnName] < lim_sup) & (dfInsurance[columnName] > lim_inf)], ax=axes[0,0])
    sns.scatterplot(x='atr_cust_age', y=columnName, hue='dsc_edu_deg', data=dfInsurance.loc[~(dfInsurance[columnName] < lim_sup) & (dfInsurance[columnName] > lim_inf)], ax=axes[0,1])

    #geographic location
    sns.scatterplot(x='atr_cust_age', y=columnName, hue='atr_gla', data=dfInsurance.loc[(dfInsurance[columnName] < lim_sup) & (dfInsurance[columnName] > lim_inf)], ax=axes[1,0])
    sns.scatterplot(x='atr_cust_age', y=columnName, hue='atr_gla', data=dfInsurance.loc[~(dfInsurance[columnName] < lim_sup) & (dfInsurance[columnName] > lim_inf)], ax=axes[1,1])

    #children
    sns.scatterplot(x='atr_cust_age', y=columnName, hue='flg_children', data=dfInsurance.loc[(dfInsurance[columnName] < lim_sup) & (dfInsurance[columnName] > lim_inf)], ax=axes[2,0])
    sns.scatterplot(x='atr_cust_age', y=columnName, hue='flg_children', data=dfInsurance.loc[~(dfInsurance[columnName] < lim_sup) & (dfInsurance[columnName] > lim_inf)], ax=axes[2,1])

# %% [markdown]
# ## Customer monetary value

# %%
negative_cmv = dfInsurance.loc[dfInsurance['amt_cmv'] < 0]
positive_cmv = dfInsurance.loc[dfInsurance['amt_cmv'] > 0]

# %% [markdown]
# #### Gross monthly salary

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))
#educational degree
sns.scatterplot(x='amt_gms', y='amt_cmv', hue='atr_gla', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0])
sns.scatterplot(x='amt_gms', y='amt_cmv', hue='atr_gla', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[1])
# Out:
# <AxesSubplot:xlabel='amt_gms', ylabel='amt_cmv'>

# %% [markdown]
# #### Claim rate

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))
#educational degree
sns.scatterplot(x='rt_cr', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0])
sns.scatterplot(x='rt_cr', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[1])
# Out:
# <AxesSubplot:xlabel='rt_cr', ylabel='amt_cmv'>

# %% [markdown]
# #### Total premiums

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))
#educational degree
sns.scatterplot(x='amt_premium_total', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0])
sns.scatterplot(x='amt_premium_total', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[1])
# Out:
# <AxesSubplot:xlabel='amt_premium_total', ylabel='amt_cmv'>

# %% [markdown]
# #### Motor premiums

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,7))
#educational degree
sns.scatterplot(x='amt_plob_motor', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,0])
sns.scatterplot(x='amt_plob_motor', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,1])

sns.scatterplot(x='amt_plob_motor', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_motor', na=False)], ax=axes[1,0])
sns.scatterplot(x='amt_plob_motor', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_motor', na=False)], ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='amt_plob_motor', ylabel='amt_cmv'>

# %% [markdown]
# #### Household premiums

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,7))
#educational degree
sns.scatterplot(x='amt_plob_household', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,0])
sns.scatterplot(x='amt_plob_household', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,1])

sns.scatterplot(x='amt_plob_household', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_household', na=False)], ax=axes[1,0])
sns.scatterplot(x='amt_plob_household', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_household', na=False)], ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='amt_plob_household', ylabel='amt_cmv'>

# %% [markdown]
# #### Health premiums

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,7))
#educational degree
sns.scatterplot(x='amt_plob_health', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,0])
sns.scatterplot(x='amt_plob_health', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,1])

sns.scatterplot(x='amt_plob_health', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_health', na=False)], ax=axes[1,0])
sns.scatterplot(x='amt_plob_health', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_health', na=False)], ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='amt_plob_health', ylabel='amt_cmv'>

# %% [markdown]
# #### Life premiums

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,7))
#educational degree
sns.scatterplot(x='amt_plob_life', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,0])
sns.scatterplot(x='amt_plob_life', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,1])

sns.scatterplot(x='amt_plob_life', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_life', na=False)], ax=axes[1,0])
sns.scatterplot(x='amt_plob_life', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_life', na=False)], ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='amt_plob_life', ylabel='amt_cmv'>

# %% [markdown]
# #### Work compensation premiums

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,7))
#educational degree
sns.scatterplot(x='amt_plob_wcomp', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,0])
sns.scatterplot(x='amt_plob_wcomp', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv', na=False)], ax=axes[0,1])

sns.scatterplot(x='amt_plob_wcomp', y='amt_cmv', data=negative_cmv.loc[~negative_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_wcomp', na=False)], ax=axes[1,0])
sns.scatterplot(x='amt_plob_wcomp', y='amt_cmv', data=positive_cmv.loc[~positive_cmv['outlier_candidate'].str.contains('amt_cmv|amt_plob_wcomp', na=False)], ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='amt_plob_wcomp', ylabel='amt_cmv'>

# %%
dfInsuranceA = dfInsurance.copy()

# %%
dfInsuranceA = dfInsurance.loc[~((dfInsurance['dt_fpy'] > 2022) | 
                        (dfInsurance['atr_cust_age'] > 100) | 
                        (dfInsurance['amt_cmv'] < -160000) |
                        (dfInsurance['amt_gms']> 15000) |
                        (dfInsurance['rt_cr'] > 2) |
                        (dfInsurance['amt_plob_motor'] > 2000)|
                        (dfInsurance['amt_plob_household'] > 5000)|
                        (dfInsurance['amt_plob_health'] > 5000)|
                        (dfInsurance['amt_plob_wcomp'] > 500)|
                        (dfInsurance['amt_premium_total'] > 5000))]

# %%
dfInsuranceA.isna().sum()
# Out:
# cod_cust_id                       0
# dt_fpy                            0
# atr_cust_age                      0
# dsc_edu_deg                      17
# amt_gms                           0
# atr_gla                           0
# flg_children                      0
# amt_cmv                           0
# rt_cr                             0
# amt_plob_motor                    0
# amt_plob_household                0
# amt_plob_health                   0
# amt_plob_life                     0
# amt_plob_wcomp                    0
# atr_edu_deg                       0
# outlier_candidate              9555
# amt_premium_total                 0
# DATA_MAIN_CUT                     0
# atr_fpy_to_date                   0
# rt_plob_life                      0
# rt_plob_household                 0
# rt_plob_motor                     0
# rt_plob_health                    0
# rt_plob_wcomp                     0
# fe_bin_plob_motor                 0
# fe_bin_plob_life                  0
# fe_bin_plob_health                0
# fe_bin_plob_wcomp                 0
# fe_bin_plob_household             0
# fe_cmv_cr_quadrant_Type1          0
# fe_cmv_cr_quadrant_Type2          0
# fe_amt_plob_motor_scale           0
# fe_amt_plob_life_scale            0
# fe_amt_plob_health_scale          0
# fe_amt_plob_wcomp_scale           0
# fe_amt_plob_household_scale       0
# Clusters_1                        0
# test_feature                      0
# dtype: int64

# %%
#dfInsuranceA.dropna(subset=['amt_plob_wcomp'], axis= 0, inplace=True)
dfInsuranceA = dfInsuranceA[dfInsuranceA['amt_plob_wcomp'].notna()]

# %%
dfInsuranceA['amt_gms'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dfInsuranceA['amt_plob_motor'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dfInsuranceA['amt_plob_life'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dfInsuranceA['amt_cmv'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#dfInsuranceA['amt_plob_wcomp_log'].plot(kind='hist', bins=20)

# %% [markdown]
# premium life, household e work compensation com distribuições power law?
#
# premium motor, health e gms com distribuição normal?
#
# amt_cmv ???

# %% [markdown]
# # PCA 2

# %%
pca_columns = [column for column in dfInsuranceA.select_dtypes(include=['int64', 'float64']) if column not in ['cod_cust_id', 'Clusters_1', 'test_feature']]

# %%
# Do feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled = sc.fit_transform(dfInsuranceA[pca_columns])

# Apply PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=None)
pca.fit(X_scaled)

# Get the eigenvalues
print("Eigenvalues:")
print(pca.explained_variance_)
print()

# Get explained variances
print("Variances (Percentage):")
print(pca.explained_variance_ratio_ * 100)
print()

# Make the scree plot
plt.plot(np.cumsum(pca.explained_variance_ratio_ * 100))
plt.xlabel("Number of components (Dimensions)")
plt.ylabel("Explained variance (%)")
# Out:
# Eigenvalues:
# [1.48034511e+01 5.78487415e+00 4.20434498e+00 3.98373224e+00
#  3.24776636e+00 2.63343698e+00 2.44383367e+00 1.00004035e+00
#  6.99485011e-01 6.09504601e-01 4.09864141e-01 3.24895978e-01
#  2.66071405e-01 1.43456162e-01 1.33892225e-01 7.12036497e-02
#  5.14907861e-02 4.53322358e-02 3.38396354e-02 2.83585473e-02
#  2.55948720e-02 1.77722534e-02 1.43075556e-02 1.26382862e-02
#  7.25861131e-03 4.36427721e-03 1.54241303e-03 5.86714965e-04
#  4.89972762e-04 2.82139073e-04 1.88901043e-04 9.09267006e-05
#  1.24109891e-05 9.86507513e-29 1.19543845e-31 1.19543845e-31
#  1.19543845e-31 1.19543845e-31 1.19543845e-31 1.19543845e-31
#  1.19543845e-31]
#
# Variances (Percentage):
# [3.61024530e+01 1.41080715e+01 1.02534987e+01 9.71547142e+00
#  7.92060794e+00 6.42238990e+00 5.95998795e+00 2.43888465e+00
#  1.70589443e+00 1.48645144e+00 9.99571031e-01 7.92351844e-01
#  6.48891283e-01 3.49858916e-01 3.26534517e-01 1.73650482e-01
#  1.25575021e-01 1.10555633e-01 8.25276376e-02 6.91604352e-02
#  6.24204219e-02 4.33427273e-02 3.48930699e-02 3.08220787e-02
#  1.77022015e-02 1.06435393e-02 3.76161568e-03 1.43087239e-03
#  1.19493883e-03 6.88076892e-04 4.60689266e-04 2.21750787e-04
#  3.02677495e-05 2.40588096e-28 2.91541886e-31 2.91541886e-31
#  2.91541886e-31 2.91541886e-31 2.91541886e-31 2.91541886e-31
#  2.91541886e-31]
# Text(0, 0.5, 'Explained variance (%)')

# %%
# Do feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled = sc.fit_transform(dfInsuranceA[pca_columns])

# Apply PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=6)
X_pca = pca.fit_transform(X_scaled)

# Get the transformed dataset
X_pca = pd.DataFrame(X_pca)
print(X_pca.head())
print("\nSize: ")
print(X_pca.shape)
# Out:
#           0         1         2         3         4         5
# 0 -1.120382  0.695774  1.191184  0.081751 -0.567337 -0.949268
# 1  6.990682  1.494606  4.670162 -0.033970  1.662856 -2.245342
# 2  3.475208  0.933670  0.358894  1.959164  2.303048  0.853637
# 3  0.836977 -4.444086  1.714379  1.425528 -3.364951 -0.423632
# 4 -1.339166 -1.329708  1.686612  0.438526 -0.935985  0.900805
#
# Size:
# (10242, 6)

# %%
fig = plt.figure(figsize=(10, 8))
sns.heatmap(X_pca.corr(), 
            annot=True)
# Out:
# <AxesSubplot:>

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X_pca)
clust_labels = kmeans.predict(X_pca)
cent = kmeans.cluster_centers_
kmeans = pd.DataFrame(clust_labels)

# %%
plt.figure(figsize=(10, 8))
# K-means clustering
plt.scatter(X_pca[0],X_pca[5],
                     c=kmeans[0], cmap='viridis')
plt.scatter(cent[:, 0], cent[:, 1],c='red', marker='*', s=300, alpha=0.6, label='centers')
plt.legend(loc='best')
plt.title('K-means clustering')
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# Text(0, 0.5, 'PC2')

# %% [markdown]
# # PCA

# %%
#Normalize features


dfInsuranceA['sqrt_amt_cmv'] = np.where(min(dfInsuranceA['amt_cmv']) <= 0,
np.sqrt(dfInsuranceA['amt_cmv'] + abs(min(dfInsuranceA['amt_cmv'])) + 1),
np.sqrt(dfInsuranceA['amt_cmv']))

dfInsuranceA['log_amt_plob_life'] = np.where(min(dfInsuranceA['amt_plob_life']) <= 0,
np.log(dfInsuranceA['amt_plob_life'] + abs(min(dfInsuranceA['amt_plob_life'])) + 1),
np.log(dfInsuranceA['amt_plob_life']))

dfInsuranceA['log_amt_plob_household'] = np.where(min(dfInsuranceA['amt_plob_household']) <= 0,
np.log(dfInsuranceA['amt_plob_household'] + abs(min(dfInsuranceA['amt_plob_household'])) + 1),
np.log(dfInsuranceA['amt_plob_household']))

dfInsuranceA['log_amt_plob_wcomp'] = np.where(min(dfInsuranceA['amt_plob_wcomp']) <= 0,
np.log(dfInsuranceA['amt_plob_wcomp'] + abs(min(dfInsuranceA['amt_plob_wcomp'])) + 1),
np.log(dfInsuranceA['amt_plob_wcomp']))

dfInsuranceA['log_amt_premium_total'] = np.where(min(dfInsuranceA['amt_premium_total']) <= 0,
np.log(dfInsuranceA['amt_premium_total'] + abs(min(dfInsuranceA['amt_premium_total'])) + 1),
np.log(dfInsuranceA['amt_premium_total']))

dfInsuranceA['log_rt_plob_life'] = np.where(min(dfInsuranceA['rt_plob_life']) <= 0,
np.log(dfInsuranceA['rt_plob_life'] + abs(min(dfInsuranceA['rt_plob_life'])) + 1),
np.log(dfInsuranceA['rt_plob_life']))

dfInsuranceA['log_rt_plob_household'] = np.where(min(dfInsuranceA['rt_plob_household']) <= 0,
np.log(dfInsuranceA['rt_plob_household'] + abs(min(dfInsuranceA['rt_plob_household'])) + 1),
np.log(dfInsuranceA['rt_plob_household']))

dfInsuranceA['log_rt_plob_motor'] = np.where(min(dfInsuranceA['rt_plob_motor']) <= 0,
np.log(dfInsuranceA['rt_plob_motor'] + abs(min(dfInsuranceA['rt_plob_motor'])) + 1),
np.log(dfInsuranceA['rt_plob_motor']))

dfInsuranceA['log_rt_plob_health'] = np.where(min(dfInsuranceA['rt_plob_health']) <= 0,
np.log(dfInsuranceA['rt_plob_health'] + abs(min(dfInsuranceA['rt_plob_health'])) + 1),
np.log(dfInsuranceA['rt_plob_health']))

dfInsuranceA['log_rt_plob_wcomp'] = np.where(min(dfInsuranceA['rt_plob_wcomp']) <= 0,
np.log(dfInsuranceA['rt_plob_wcomp'] + abs(min(dfInsuranceA['rt_plob_wcomp'])) + 1),
np.log(dfInsuranceA['rt_plob_wcomp']))


scaler = MinMaxScaler()
dfInsuranceA['minmax_amt_plob_health'] = scaler.fit_transform(dfInsuranceA[['amt_plob_health']])
dfInsuranceA['minmax_amt_plob_motor'] = scaler.fit_transform(dfInsuranceA[['amt_plob_motor']])
dfInsuranceA['minmax_amt_gms'] = scaler.fit_transform(dfInsuranceA[['amt_gms']])
dfInsuranceA['minmax_atr_cust_age'] = scaler.fit_transform(dfInsuranceA[['atr_cust_age']])
dfInsuranceA['minmax_dt_fpy'] = scaler.fit_transform(dfInsuranceA[['dt_fpy']])
dfInsuranceA['minmax_fpy_to_date'] = scaler.fit_transform(dfInsuranceA[['atr_fpy_to_date']])


#features_dataset = dfInsuranceA[['minmax_amt_plob_health', 'minmax_amt_plob_motor', 'minmax_amt_gms', 'log_amt_cmv', 'log_amt_plob_life', 'log_amt_plob_household', 'log_amt_plob_wcomp']]
# Out:
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from sklearn.preprocessing import StandardScaler

# %%
dfInsurance_scaler = StandardScaler()

# %%
df_temp = dfInsuranceA.drop(columns=['dsc_edu_deg'], inplace=True)

# %%
df = dfInsuranceA[['amt_cmv','amt_gms','amt_plob_motor', 'amt_plob_household', 'amt_plob_wcomp', 'amt_plob_life']]

# %%
df = dfInsurance_scaler.fit_transform(df)

# %%
df_scaled = pd.DataFrame(df, columns=['amt_cmv','amt_gms','amt_plob_motor', 'amt_plob_household', 'amt_plob_wcomp', 'amt_plob_life'])

# %%
df_scaled.head()
# Out:
#     amt_cmv   amt_gms  amt_plob_motor  amt_plob_household  amt_plob_wcomp  \
# 0  0.628069 -0.325888        0.570515           -0.534139       -0.512397
# 1 -1.350526 -1.851381       -1.592250            0.872031        1.394818
# 2  1.106007 -0.224223       -0.659490            0.071547        1.242865
# 3 -0.909524 -1.422352       -0.831053           -0.684883       -0.267690
# 4 -0.707763 -0.746784        0.300668           -0.666301        0.012493
#
#    amt_plob_life
# 0       0.113318
# 1       3.226038
# 2       0.943686
# 3      -0.133007
# 4      -0.482547

# %%
df = dfInsuranceA[['amt_cmv','amt_gms','amt_plob_motor', 'amt_plob_household', 'amt_plob_wcomp', 'amt_plob_life']]

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(df)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principalDf.head()
# Out:
#    principal component 1  principal component 2
# 0            -637.022880               4.174887
# 1           -3647.682236            -176.292073
# 2            -445.883712             234.909680
# 3           -2791.318367            -334.828471
# 4           -1461.172710            -288.678843

# %%
sns.scatterplot(data = principalDf, x='principal component 1', y='principal component 2');

# %%
# clusters = pd.read_csv('../data/clusters_1.csv')

# %%
# clusters.head()

# %%
# principalDf.shape

# %%
# clusters.shape

# %%
# principalDf = principalDf.merge(clusters, right_index=True)

# %%
# principalDf.shape

# %%
plt.figure(figsize=(12, 8));
sns.scatterplot(data = principalDf, x = 'principal component 1', y = 'principal component 2', 
                hue = dfInsuranceA['Clusters_1'], palette='tab10');

# %%
dfInsuranceA.columns
# Out:
# Index(['cod_cust_id', 'dt_fpy', 'atr_cust_age', 'amt_gms', 'atr_gla',
#        'flg_children', 'amt_cmv', 'rt_cr', 'amt_plob_motor',
#        'amt_plob_household', 'amt_plob_health', 'amt_plob_life',
#        'amt_plob_wcomp', 'atr_edu_deg', 'outlier_candidate',
#        'amt_premium_total', 'DATA_MAIN_CUT', 'atr_fpy_to_date', 'rt_plob_life',
#        'rt_plob_household', 'rt_plob_motor', 'rt_plob_health', 'rt_plob_wcomp',
#        'fe_bin_plob_motor', 'fe_bin_plob_life', 'fe_bin_plob_health',
#        'fe_bin_plob_wcomp', 'fe_bin_plob_household',
#        'fe_cmv_cr_quadrant_Type1', 'fe_cmv_cr_quadrant_Type2',
#        'fe_amt_plob_motor_scale', 'fe_amt_plob_life_scale',
#        'fe_amt_plob_health_scale', 'fe_amt_plob_wcomp_scale',
#        'fe_amt_plob_household_scale', 'Clusters_1', 'test_feature',
#        'sqrt_amt_cmv', 'log_amt_plob_life', 'log_amt_plob_household',
#        'log_amt_plob_wcomp', 'minmax_amt_plob_health', 'minmax_amt_plob_motor',
#        'minmax_amt_gms'],
#       dtype='object')

# %%
df = dfInsuranceA[['sqrt_amt_cmv','minmax_amt_gms','minmax_amt_plob_motor', 'log_amt_plob_household', 'log_amt_plob_wcomp', 'log_amt_plob_life']]

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(df)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
plt.figure(figsize=(12, 8));
sns.scatterplot(data = principalDf, x = 'principal component 1', y = 'principal component 2', 
                hue = dfInsuranceA['Clusters_1'], palette='tab10');

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#df = dfInsuranceA[['sqrt_amt_cmv','minmax_amt_gms','minmax_amt_plob_motor', 'log_amt_plob_household', 'log_amt_plob_wcomp', 'log_amt_plob_life']]
df = dfInsuranceA[['minmax_amt_gms','minmax_amt_plob_motor', 'log_amt_plob_household', 'log_amt_plob_wcomp', 'log_amt_plob_life']]

pca_reducer = PCA(n_components=2)
reduced_data = pca_reducer.fit_transform(df)
reduced_data = pd.DataFrame(data = reduced_data)

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(reduced_data)
clust_labels = kmeans.predict(reduced_data)
cent = kmeans.cluster_centers_
kmeans = pd.DataFrame(clust_labels)

# %%
plt.figure(figsize=(10, 8))
# K-means clustering
plt.scatter(reduced_data[0],reduced_data[1],
                     c=kmeans[0], cmap='viridis')
plt.scatter(cent[:, 0], cent[:, 1],c='red', marker='*', s=300, alpha=0.6, label='centers')
plt.legend(loc='best')
plt.title('K-means clustering')
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# Text(0, 0.5, 'PC2')

# %%
np.random.seed(42)
if "Set" not in dfInsurance.columns:
    dfInsuranceA["Set"] = np.random.choice(["train", "test"], p =[.7, .3], size=(dfInsuranceA.shape[0],))
    
dfTrain = dfInsuranceA.loc[dfInsuranceA.Set == 'train']
dfVal = dfInsuranceA.loc[dfInsuranceA.Set == 'test']

# %%
dfInsuranceA.head()
# Out:
#    cod_cust_id  dt_fpy  atr_cust_age  amt_gms  atr_gla  flg_children  amt_cmv  \
# 0            1    1985            34   4354.0        1             1   380.97
# 1            2    1981            21   1353.0        4             1  -131.13
# 2            3    1991            46   4554.0        3             0   504.67
# 3            4    1990            35   2197.0        4             1   -16.99
# 4            5    1986            43   3526.0        4             1    35.23
#
#       rt_cr  amt_plob_motor  amt_plob_household  ...  Clusters_1  \
# 0  0.390032          375.85               79.45  ...           2
# 1  1.116503           77.46              416.20  ...           3
# 2  0.284810          206.15              224.50  ...           3
# 3  0.986665          182.48               43.35  ...           2
# 4  0.904281          338.62               47.80  ...           0
#
#    test_feature  sqrt_amt_cmv  log_amt_plob_life log_amt_plob_household  \
# 0     12.020119     29.532524           4.007515               5.046324
# 1     12.017030     18.975511           5.310641               6.198885
# 2     12.020863     31.557408           4.547011               5.705448
# 3     12.017720     21.776363           3.769076               4.782060
# 4     12.018035     22.944062           3.287655               4.818667
#
#    log_amt_plob_wcomp minmax_amt_plob_health  minmax_amt_plob_motor  \
# 0            3.397524               0.333663               0.644732
# 1            4.780215               0.266984               0.138411
# 2            4.718677               0.284716               0.356778
# 3            3.721831               0.704047               0.316614
# 4            3.997283               0.415084               0.581559
#
#    minmax_amt_gms    Set
# 0        0.393409  train
# 1        0.073371   test
# 2        0.414738   test
# 3        0.163378  train
# 4        0.305108  train
#
# [5 rows x 45 columns]

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(dfTrain[['minmax_amt_gms','minmax_amt_plob_motor', 'log_amt_plob_household', 'log_amt_plob_wcomp', 'log_amt_plob_life']])
dfInsuranceA['clusters'] = kmeans.predict(dfInsuranceA[['minmax_amt_gms','minmax_amt_plob_motor', 'log_amt_plob_household', 'log_amt_plob_wcomp', 'log_amt_plob_life']])

#dfInsuranceA['clusters'] = kmeans.predict(dfInsuranceA[['minmax_amt_gms','minmax_amt_plob_motor', 'log_amt_plob_household', 'log_amt_plob_wcomp', 'log_amt_plob_life']])

# %%
clust_labels
# Out:
# array([2, 0, 0, ..., 2, 0, 1])

# %%
cent = kmeans.cluster_centers_
kmeans = pd.DataFrame(dfInsuranceA['clusters'])

# %%
plt.figure(figsize=(10, 8))
# K-means clustering
plt.scatter(dfInsuranceA['sqrt_amt_cmv'],dfInsuranceA['minmax_amt_plob_motor'],
                     c=dfInsuranceA['clusters'], cmap='viridis')
plt.scatter(cent[:, 0], cent[:, 1],c='red', marker='*', s=300, alpha=0.6, label='centers')
plt.legend(loc='best')
plt.title('K-means clustering')
plt.xlabel('sqrt_amt_cmv')
plt.ylabel('minmax_amt_plob_motor')
# Out:
# Text(0, 0.5, 'minmax_amt_plob_motor')

# %%
dfTrain.columns
# Out:
# Index(['cod_cust_id', 'dt_fpy', 'atr_cust_age', 'amt_gms', 'atr_gla',
#        'flg_children', 'amt_cmv', 'rt_cr', 'amt_plob_motor',
#        'amt_plob_household', 'amt_plob_health', 'amt_plob_life',
#        'amt_plob_wcomp', 'atr_edu_deg', 'outlier_candidate',
#        'amt_premium_total', 'DATA_MAIN_CUT', 'atr_fpy_to_date', 'rt_plob_life',
#        'rt_plob_household', 'rt_plob_motor', 'rt_plob_health', 'rt_plob_wcomp',
#        'fe_bin_plob_motor', 'fe_bin_plob_life', 'fe_bin_plob_health',
#        'fe_bin_plob_wcomp', 'fe_bin_plob_household',
#        'fe_cmv_cr_quadrant_Type1', 'fe_cmv_cr_quadrant_Type2',
#        'fe_amt_plob_motor_scale', 'fe_amt_plob_life_scale',
#        'fe_amt_plob_health_scale', 'fe_amt_plob_wcomp_scale',
#        'fe_amt_plob_household_scale', 'Clusters_1', 'test_feature',
#        'sqrt_amt_cmv', 'log_amt_plob_life', 'log_amt_plob_household',
#        'log_amt_plob_wcomp', 'minmax_amt_plob_health', 'minmax_amt_plob_motor',
#        'minmax_amt_gms', 'Set'],
#       dtype='object')

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(dfTrain[['log_amt_plob_household','minmax_amt_plob_motor']])
# dfInsuranceA['clusters'] = kmeans.predict(dfInsuranceA[['sqrt_amt_cmv', 'minmax_amt_gms','minmax_amt_plob_motor']])
# cent = kmeans.cluster_centers_
# kmeans = pd.DataFrame(dfInsuranceA['clusters'])
clust_labels = kmeans.predict(dfVal[['log_amt_plob_household','minmax_amt_plob_health']])
cent = kmeans.cluster_centers_
kmeans = pd.DataFrame(clust_labels)

plt.figure(figsize=(10, 8))
# K-means clustering
plt.scatter(dfVal['log_amt_plob_household'],dfVal['minmax_amt_plob_health'],
                     c=kmeans[0], cmap='viridis')
plt.scatter(cent[:, 0], cent[:, 1],c='red', marker='*', s=300, alpha=0.6, label='centers')
plt.legend(loc='best')
plt.title('K-means clustering')
plt.xlabel('log_amt_plob_household')
plt.ylabel('minmax_amt_plob_health')
# Out:
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - minmax_amt_plob_health
# Feature names seen at fit time, yet now missing:
# - minmax_amt_plob_motor
#
#   warnings.warn(message, FutureWarning)
# Text(0, 0.5, 'minmax_amt_plob_health')

# %%
kmeans[0]
# Out:
# 0        1
# 1        2
# 2        0
# 3        2
# 4        2
#         ..
# 10237    2
# 10238    0
# 10239    0
# 10240    1
# 10241    0
# Name: 0, Length: 10242, dtype: int32

# %%
dfInsuranceA['clusters']
# Out:
# 0        0
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 10265    1
# 10266    2
# 10267    2
# 10268    0
# 10269    2
# Name: clusters, Length: 10242, dtype: int32

# %% [markdown]
# # t-SNE

# %%
from sklearn.manifold import TSNE
 
# We want to get TSNE embedding with 2 dimensions
n_components = 2
tsne = TSNE(n_components)
tsne_result = tsne.fit_transform(df)
tsne_result.shape
# (1000, 2)
# Two dimensions for each of our images
 
# Plot the result of our TSNE with the label color coded
# A lot of the stuff here is about making the plot look pretty and not TSNE
tsne_result_df = pd.DataFrame({'tsne_1': tsne_result[:,0], 'tsne_2': tsne_result[:,1], 'label': dfInsuranceA['clusters']})
fig, ax = plt.subplots(1)
plt.figure(figsize=(10,11))
sns.scatterplot(x='tsne_1', y='tsne_2', hue='label', data=tsne_result_df, ax=ax,s=16)
lim = (tsne_result.min()-5, tsne_result.max()+5)
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
# Out:
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\PedroSantos\anaconda3\envs\dsacademy\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ## Claims Rate Segmentation

# %%
dfInsuranceA.columns
# Out:
# Index(['cod_cust_id', 'dt_fpy', 'atr_cust_age', 'amt_gms', 'atr_gla',
#        'flg_children', 'amt_cmv', 'rt_cr', 'amt_plob_motor',
#        'amt_plob_household', 'amt_plob_health', 'amt_plob_life',
#        'amt_plob_wcomp', 'atr_edu_deg', 'outlier_candidate',
#        'amt_premium_total', 'DATA_MAIN_CUT', 'atr_fpy_to_date', 'rt_plob_life',
#        'rt_plob_household', 'rt_plob_motor', 'rt_plob_health', 'rt_plob_wcomp',
#        'fe_bin_plob_motor', 'fe_bin_plob_life', 'fe_bin_plob_health',
#        'fe_bin_plob_wcomp', 'fe_bin_plob_household',
#        'fe_cmv_cr_quadrant_Type1', 'fe_cmv_cr_quadrant_Type2',
#        'fe_amt_plob_motor_scale', 'fe_amt_plob_life_scale',
#        'fe_amt_plob_health_scale', 'fe_amt_plob_wcomp_scale',
#        'fe_amt_plob_household_scale', 'Clusters_1', 'test_feature',
#        'sqrt_amt_cmv', 'log_amt_plob_life', 'log_amt_plob_household',
#        'log_amt_plob_wcomp', 'log_amt_premium_total', 'log_rt_plob_life',
#        'log_rt_plob_household', 'log_rt_plob_motor', 'log_rt_plob_health',
#        'log_rt_plob_wcomp', 'minmax_amt_plob_health', 'minmax_amt_plob_motor',
#        'minmax_amt_gms', 'minmax_atr_cust_age', 'minmax_dt_fpy',
#        'minmax_fpy_to_date', 'Set', 'clusters'],
#       dtype='object')

# %%
dfInsuranceA['rt_cr'].describe()
# Out:
# count    10242.000000
# mean         0.679898
# std          0.318872
# min          0.000000
# 25%          0.392313
# 50%          0.719198
# 75%          0.976025
# max          1.620145
# Name: rt_cr, dtype: float64

# %%
dfInsuranceA['amt_premium_total'].describe()
# Out:
# count    10242.000000
# mean       754.994074
# std        195.963989
# min        429.190000
# 25%        627.240000
# 50%        698.663000
# 75%        824.160000
# max       4730.700000
# Name: amt_premium_total, dtype: float64

# %%
dfInsuranceA['atr_current_age'] = dfInsuranceA['atr_cust_age'] + dfInsuranceA['atr_fpy_to_date']

# %%
dfInsuranceA['atr_current_age'] = dfInsuranceA['atr_current_age'].astype('int64')

# %%
dfInsuranceA.columns
# Out:
# Index(['cod_cust_id', 'dt_fpy', 'atr_cust_age', 'amt_gms', 'atr_gla',
#        'flg_children', 'amt_cmv', 'rt_cr', 'amt_plob_motor',
#        'amt_plob_household', 'amt_plob_health', 'amt_plob_life',
#        'amt_plob_wcomp', 'atr_edu_deg', 'outlier_candidate',
#        'amt_premium_total', 'DATA_MAIN_CUT', 'atr_fpy_to_date', 'rt_plob_life',
#        'rt_plob_household', 'rt_plob_motor', 'rt_plob_health', 'rt_plob_wcomp',
#        'fe_bin_plob_motor', 'fe_bin_plob_life', 'fe_bin_plob_health',
#        'fe_bin_plob_wcomp', 'fe_bin_plob_household',
#        'fe_cmv_cr_quadrant_Type1', 'fe_cmv_cr_quadrant_Type2',
#        'fe_amt_plob_motor_scale', 'fe_amt_plob_life_scale',
#        'fe_amt_plob_health_scale', 'fe_amt_plob_wcomp_scale',
#        'fe_amt_plob_household_scale', 'Clusters_1', 'test_feature',
#        'sqrt_amt_cmv', 'log_amt_plob_life', 'log_amt_plob_household',
#        'log_amt_plob_wcomp', 'log_amt_premium_total', 'log_rt_plob_life',
#        'log_rt_plob_household', 'log_rt_plob_motor', 'log_rt_plob_health',
#        'log_rt_plob_wcomp', 'minmax_amt_plob_health', 'minmax_amt_plob_motor',
#        'minmax_amt_gms', 'minmax_atr_cust_age', 'minmax_dt_fpy',
#        'minmax_fpy_to_date', 'Set', 'clusters', 'atr_current_age'],
#       dtype='object')

# %% [markdown]
# ## Claims Rate Filter

# %%
claims_rate_filter = dfInsuranceA[(dfInsuranceA['rt_cr'] < 0.5) & (dfInsuranceA['amt_premium_total'] > 1000)]

# %%
claims_rate_filter
# Out:
#        cod_cust_id  dt_fpy  atr_cust_age  amt_gms  atr_gla  flg_children  \
# 45              46    1991            32   3874.0        3             1
# 101            102    1981            60   5387.0        3             1
# 155            156    1986            24   2708.0        3             0
# 191            192    1996            22   2972.0        2             0
# 236            237    1987            68   7145.0        4             0
# ...            ...     ...           ...      ...      ...           ...
# 10202        10229    1978            20   1687.0        3             0
# 10203        10230    1977            62   6558.0        4             1
# 10204        10231    1991            20   3188.0        3             0
# 10262        10289    1982            23   2930.0        1             1
# 10266        10293    1977            64   4862.0        3             0
#
#        amt_cmv     rt_cr  amt_plob_motor  amt_plob_household  ...  \
# 45      624.34  0.376947          139.58              540.10  ...
# 101     654.90  0.386792           62.68              648.45  ...
# 155     589.33  0.433609          100.13              614.55  ...
# 191     872.07  0.119164          106.02              587.90  ...
# 236     752.03  0.270148          152.25              579.55  ...
# ...        ...       ...             ...                 ...  ...
# 10202  1041.42  0.248259           51.01             1045.75  ...
# 10203   606.56  0.409315          239.60              604.00  ...
# 10204  1083.11  0.138348           42.34              877.40  ...
# 10262   795.15  0.348575           67.79              820.15  ...
# 10266  1405.60  0.000000          133.58             1035.75  ...
#
#        log_rt_plob_wcomp  minmax_amt_plob_health  minmax_amt_plob_motor  \
# 45              0.093009                0.410589               0.243819
# 101             0.153129                0.477021               0.113332
# 155             0.066926                0.728027               0.176879
# 191             0.220153                0.176574               0.186873
# 236             0.065070                0.529968               0.265318
# ...                  ...                     ...                    ...
# 10202           0.038568                0.560442               0.093530
# 10203           0.089343                0.284716               0.413537
# 10204           0.126342                0.309437               0.078818
# 10262           0.089313                0.234263               0.122003
# 10266           0.093706                0.326674               0.233638
#
#        minmax_amt_gms minmax_atr_cust_age  minmax_dt_fpy minmax_fpy_to_date  \
# 45           0.342220            0.257576       0.708333           0.291667
# 101          0.503573            0.681818       0.291667           0.708333
# 155          0.217874            0.136364       0.500000           0.500000
# 191          0.246028            0.106061       0.916667           0.083333
# 236          0.691053            0.803030       0.541667           0.458333
# ...               ...                 ...            ...                ...
# 10202        0.108990            0.075758       0.166667           0.833333
# 10203        0.628453            0.712121       0.125000           0.875000
# 10204        0.269063            0.075758       0.708333           0.291667
# 10262        0.241548            0.121212       0.333333           0.666667
# 10266        0.447585            0.742424       0.125000           0.875000
#
#          Set  clusters  atr_current_age
# 45     train         2               40
# 101    train         2               78
# 155    train         1               37
# 191    train         2               25
# 236    train         2               80
# ...      ...       ...              ...
# 10202  train         2               41
# 10203  train         2               84
# 10204   test         2               28
# 10262   test         2               40
# 10266   test         2               86
#
# [485 rows x 56 columns]

# %%
claims_rate_filter['rt_cr'].describe()
# Out:
# count    485.000000
# mean       0.292151
# std        0.117220
# min        0.000000
# 25%        0.213187
# 50%        0.290137
# 75%        0.386792
# max        0.498407
# Name: rt_cr, dtype: float64

# %%
plt.figure(figsize=(19, 10));
sns.barplot(x='atr_current_age', y='rt_cr', data=claims_rate_filter, palette='tab10', ci=None);

# %%
plt.figure(figsize=(12, 10));
sns.scatterplot(x='rt_cr', y='amt_plob_motor', data=claims_rate_filter, hue='flg_children');

# %%
plt.figure(figsize=(12, 10));
sns.scatterplot(x='rt_cr', y='amt_plob_household', data=claims_rate_filter, hue='flg_children');

# %%
plt.figure(figsize=(12, 10));
sns.scatterplot(x='rt_cr', y='amt_plob_health', data=claims_rate_filter, hue='flg_children');

# %%
plt.figure(figsize=(12, 10));
sns.scatterplot(x='rt_cr', y='amt_plob_life', data=claims_rate_filter, hue='flg_children');

# %%
plt.figure(figsize=(12, 10));
sns.scatterplot(x='rt_cr', y='amt_plob_wcomp', data=claims_rate_filter, hue='flg_children');

# %%
plt.figure(figsize=(12, 10));
sns.scatterplot(x='rt_cr', y='amt_premium_total', data=claims_rate_filter, hue='flg_children');

# %%
claims_rate_filter.columns
# Out:
# Index(['cod_cust_id', 'dt_fpy', 'atr_cust_age', 'amt_gms', 'atr_gla',
#        'flg_children', 'amt_cmv', 'rt_cr', 'amt_plob_motor',
#        'amt_plob_household', 'amt_plob_health', 'amt_plob_life',
#        'amt_plob_wcomp', 'atr_edu_deg', 'outlier_candidate',
#        'amt_premium_total', 'DATA_MAIN_CUT', 'atr_fpy_to_date', 'rt_plob_life',
#        'rt_plob_household', 'rt_plob_motor', 'rt_plob_health', 'rt_plob_wcomp',
#        'fe_bin_plob_motor', 'fe_bin_plob_life', 'fe_bin_plob_health',
#        'fe_bin_plob_wcomp', 'fe_bin_plob_household',
#        'fe_cmv_cr_quadrant_Type1', 'fe_cmv_cr_quadrant_Type2',
#        'fe_amt_plob_motor_scale', 'fe_amt_plob_life_scale',
#        'fe_amt_plob_health_scale', 'fe_amt_plob_wcomp_scale',
#        'fe_amt_plob_household_scale', 'Clusters_1', 'test_feature',
#        'sqrt_amt_cmv', 'log_amt_plob_life', 'log_amt_plob_household',
#        'log_amt_plob_wcomp', 'log_amt_premium_total', 'log_rt_plob_life',
#        'log_rt_plob_household', 'log_rt_plob_motor', 'log_rt_plob_health',
#        'log_rt_plob_wcomp', 'minmax_amt_plob_health', 'minmax_amt_plob_motor',
#        'minmax_amt_gms', 'minmax_atr_cust_age', 'minmax_dt_fpy',
#        'minmax_fpy_to_date', 'Set', 'clusters'],
#       dtype='object')
